# %%
import pandas as pd

# %%
owners = pd.read_csv("Business_Owners_20240103.csv")
licenses = pd.read_csv("Business_Licenses_20240103.csv")
contracts = pd.read_csv("Contracts_20240103.csv")
# Out:
# /var/folders/vv/q2ykgsqj4338jvfxhd92l4xc0000gn/T/ipykernel_49887/139061379.py:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   licenses = pd.read_csv("Business_Licenses_20240103.csv")
# /var/folders/vv/q2ykgsqj4338jvfxhd92l4xc0000gn/T/ipykernel_49887/139061379.py:3: DtypeWarning: Columns (2,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   contracts = pd.read_csv("Contracts_20240103.csv")

# %% [markdown]
# # Dataset Overview

# %% [markdown]
# ## Business_Owners_20240103.csv

# %%
len(owners)
# Out:
# 312114

# %%
owners.head()
# Out:
#    Account Number                           Legal Name Owner First Name  \
# 0           57028                     A LAVA & SONS CO              LEO
# 1          458385                   NANO CLASSICS, LLC              Amy
# 2          362027  ENVIOS DE VALORES LA NACIONAL CORP.              Jon
# 3          456967          INOKO SUSHI RESTAURANT INC.         SHANSHAN
# 4           64406                SEADOG VENTURES, INC.           LAUREN
#
#   Owner Middle Initial Owner Last Name Suffix Legal Entity Owner  \
# 0                  NaN       APPELBAUM    NaN                NaN
# 1                    E   Runjavac-Duda    NaN                NaN
# 2                    C            Ness    NaN                NaN
# 3                  NaN              YU    NaN                NaN
# 4                  NaN           BARAN    NaN                NaN
#
#              Title
# 0        PRESIDENT
# 1  MANAGING MEMBER
# 2              CEO
# 3        SECRETARY
# 4        TREASURER

# %%
from splink.exploratory import completeness_chart
from splink import DuckDBAPI
db_api = DuckDBAPI()
completeness_chart(owners, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %%
from splink.exploratory import profile_columns
profile_columns(owners, db_api=DuckDBAPI(), top_n=10, bottom_n=5)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Business_Licenses_20240103.csv

# %%
len(licenses)
# Out:
# 1120768

# %%
licenses.head()
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0    16570-20000216       76522           51755            1
# 1    25710-19960216      119268           52896            1
# 2  2354557-20160916     2479692          287477            2
# 3    53383-20150316     2375632           38691            1
# 4  1847540-20090116     1940503           89020           45
#
#                                LEGAL NAME  \
# 0                  THORNDALE CONSTRUCTION
# 1                       PAT HAMILTON, INC
# 2  AMERICAN ARBITRATION ASSOCIATION, INC.
# 3                                 MEE INC
# 4   FEDEX OFFICE AND PRINT SERVICES, INC.
#
#                    DOING BUSINESS AS NAME  \
# 0                  THORNDALE CONSTRUCTION
# 1                        PAT HAMILTON CO.
# 2  AMERICAN ARBITRATION ASSOCIATION, INC.
# 3                                 MEE INC
# 4       FEDEX OFFICE AND PRINT SVCS, INC.
#
# ...

# %%
from splink.exploratory import completeness_chart
from splink import DuckDBAPI
db_api = DuckDBAPI()
completeness_chart(licenses, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %%
from splink.exploratory import profile_columns
profile_columns(licenses, db_api=DuckDBAPI(), top_n=10, bottom_n=5)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Connections Between Owners and Licenses

# %%
licenses.loc[licenses['ACCOUNT NUMBER'] == 51755]
# Out:
#                ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  16570-20000216       76522           51755            1
#
#                LEGAL NAME  DOING BUSINESS AS NAME  \
# 0  THORNDALE CONSTRUCTION  THORNDALE CONSTRUCTION
#
#                         ADDRESS         CITY STATE ZIP CODE  ...  \
# 0  11243  CHESAPEAKE PLAC   1ST  WESTCHESTER    IL    60154  ...
#
#    LICENSE TERM START DATE  LICENSE TERM EXPIRATION DATE  \
# 0               02/16/2000                    02/15/2001
#
#   LICENSE APPROVED FOR ISSUANCE  DATE ISSUED  LICENSE STATUS  \
# 0                    12/22/2003   08/24/2009             AAI
#
#   LICENSE STATUS CHANGE DATE SSA LATITUDE  LONGITUDE LOCATION
# 0                        NaN NaN      NaN        NaN      NaN
#
# [1 rows x 34 columns]

# %%
owners.loc[owners['Account Number'] == 51755]
# Out:
#         Account Number              Legal Name Owner First Name  \
# 174512           51755  THORNDALE CONSTRUCTION        ELIZABETH
# 243181           51755  THORNDALE CONSTRUCTION           THOMAS
#
#        Owner Middle Initial Owner Last Name Suffix Legal Entity Owner  \
# 174512                    J        BAUMBECK    NaN                NaN
# 243181                    H        BAUMBECK    NaN                NaN
#
#             Title
# 174512  SECRETARY
# 243181  PRESIDENT

# %% [markdown]
# ## Contracts_20240103.csv

# %%
len(contracts)
# Out:
# 168233

# %%
contracts.head()
# Out:
#                  Purchase Order Description Purchase Order (Contract) Number  \
# 0                                DEMOLITION                          E011442
# 1                       JANITORIAL SUPPLIES                           T27500
# 2  MASTER AGREEMENT FOR DEMOLITION SERVICES                           C02163
# 3  MASTER AGREEMENT FOR DEMOLITION SERVICES                           C02106
# 4  PARTS & SERVICE FOR TARGET CONCRETE SAWS                           T25387
#
#   Revision Number Specification Number Contract Type  Start Date    End Date  \
# 0               0           E968020030           NaN         NaN         NaN
# 1               0            B74851001           NaN  12/01/1997  11/30/1999
# 2               0            B89683203           NaN         NaN         NaN
# 3               0            B89683203           NaN         NaN         NaN
# 4               0            B74455802           NaN         NaN         NaN
#
# ...

# %%
from splink.exploratory import completeness_chart
from splink import DuckDBAPI
db_api = DuckDBAPI()
completeness_chart(contracts, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %%
from splink.exploratory import profile_columns
profile_columns(contracts, db_api=DuckDBAPI(), top_n=10, bottom_n=5)
# Out:
# alt.VConcatChart(...)
